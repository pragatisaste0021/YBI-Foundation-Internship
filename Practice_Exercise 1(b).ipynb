# %% [markdown]
# ##**Import library**

# %%
import pandas as pd

# %% [markdown]
# ##**Import MPG dataset and store as the pandas dataframe with name mpg**

# %%
mpg = pd.read_csv('https://github.com/YBI-Foundation/Dataset/raw/main/MPG.csv')

# %%
mpg
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %% [markdown]
# ##**Copy mpg dataframe as bike**

# %%
bike = mpg.copy()

# %%
bike
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %% [markdown]
# ##**Drop column name cylinders from original dataframe(mpg) and inspect what happened to copy(bike)**

# %%
mpg = mpg.drop('cylinders', axis = 1)

# %%
mpg.columns
# Out:
# Index(['mpg', 'displacement', 'horsepower', 'weight', 'acceleration',
#        'model_year', 'origin', 'name'],
#       dtype='object')

# %%
bike.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year', 'origin', 'name'],
#       dtype='object')

# %% [markdown]
# ##**Analyze dataframe bike**

# %%
bike.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %%
bike.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  392.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.491160   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  126.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year
# count    398.000000  398.000000
# mean      15.568090   76.010050
# std        2.757689    3.697627
# min        8.000000   70.000000
# 25%       13.825000   73.000000
# 50%       15.500000   76.000000
# 75%       17.175000   79.000000
# max       24.800000   82.000000

# %% [markdown]
# ##**Provide unique values in each columns cylinders and origin**

# %%
bike[['cylinders','origin']].value_counts()
# Out:
# cylinders  origin
# 8          usa       103
# 6          usa        74
# 4          usa        72
#            japan      69
#            europe     63
# 6          japan       6
# 3          japan       4
# 6          europe      4
# 5          europe      3
# dtype: int64

# %% [markdown]
# ##**Provide unique values of column origin**

# %%
bike[['origin']].value_counts()
# Out:
# origin
# usa       249
# japan      79
# europe     70
# dtype: int64

# %%
bike['origin'].unique()
# Out:
# array(['usa', 'japan', 'europe'], dtype=object)

# %%
bike['origin'].nunique()
# Out:
# 3

# %% [markdown]
# ##**Sort value of bike dataframe as per displacement column**

# %%
bike.sort_values('displacement')
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 117  29.0          4          68.0        49.0    1867          19.5
# 71   19.0          3          70.0        97.0    2330          13.5
# 111  18.0          3          70.0        90.0    2124          13.5
# 334  23.7          3          70.0       100.0    2420          12.5
# 131  32.0          4          71.0        65.0    1836          21.0
# ..    ...        ...           ...         ...     ...           ...
# 94   13.0          8         440.0       215.0    4735          11.0
# 6    14.0          8         454.0       220.0    4354           9.0
# 95   12.0          8         455.0       225.0    4951          11.0
# 8    14.0          8         455.0       225.0    4425          10.0
# 13   14.0          8         455.0       225.0    3086          10.0
#
#      model_year  origin                          name
# 117          73  europe                      fiat 128
# ...

# %% [markdown]
# ##**Sort value of bike dataframe as per displacement column in descending order**

# %%
bike.sort_values('displacement', ascending = False)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 8    14.0          8         455.0       225.0    4425          10.0
# 95   12.0          8         455.0       225.0    4951          11.0
# 13   14.0          8         455.0       225.0    3086          10.0
# 6    14.0          8         454.0       220.0    4354           9.0
# 7    14.0          8         440.0       215.0    4312           8.5
# ..    ...        ...           ...         ...     ...           ...
# 131  32.0          4          71.0        65.0    1836          21.0
# 111  18.0          3          70.0        90.0    2124          13.5
# 71   19.0          3          70.0        97.0    2330          13.5
# 334  23.7          3          70.0       100.0    2420          12.5
# 117  29.0          4          68.0        49.0    1867          19.5
#
#      model_year  origin                      name
# 8            70     usa          pontiac catalina
# ...

# %% [markdown]
# ##**Sort value of bike dataframe as per displacement and weight columns in descending order**

# %%
bike.sort_values(['displacement','weight'], ascending = False)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 95   12.0          8         455.0       225.0    4951          11.0
# 8    14.0          8         455.0       225.0    4425          10.0
# 13   14.0          8         455.0       225.0    3086          10.0
# 6    14.0          8         454.0       220.0    4354           9.0
# 94   13.0          8         440.0       215.0    4735          11.0
# ..    ...        ...           ...         ...     ...           ...
# 53   31.0          4          71.0        65.0    1773          19.0
# 334  23.7          3          70.0       100.0    2420          12.5
# 71   19.0          3          70.0        97.0    2330          13.5
# 111  18.0          3          70.0        90.0    2124          13.5
# 117  29.0          4          68.0        49.0    1867          19.5
#
#      model_year  origin                          name
# 95           73     usa      buick electra 225 custom
# ...

# %% [markdown]
# ##**Summary statistics of all columns**

# %%
bike.describe(include = 'all')
# Out:
#                mpg   cylinders  displacement  horsepower       weight  \
# count   398.000000  398.000000    398.000000  392.000000   398.000000
# unique         NaN         NaN           NaN         NaN          NaN
# top            NaN         NaN           NaN         NaN          NaN
# freq           NaN         NaN           NaN         NaN          NaN
# mean     23.514573    5.454774    193.425879  104.469388  2970.424623
# std       7.815984    1.701004    104.269838   38.491160   846.841774
# min       9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%      17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%      23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%      29.000000    8.000000    262.000000  126.000000  3608.000000
# max      46.600000    8.000000    455.000000  230.000000  5140.000000
#
#         acceleration  model_year origin        name
# count     398.000000  398.000000    398         398
# ...

# %% [markdown]
# ##**Tranpose dataframe**

# %%
bike.T
# Out:
#                                     0                  1    \
# mpg                                18.0               15.0
# cylinders                             8                  8
# displacement                      307.0              350.0
# horsepower                        130.0              165.0
# weight                             3504               3693
# acceleration                       12.0               11.5
# model_year                           70                 70
# origin                              usa                usa
# name          chevrolet chevelle malibu  buick skylark 320
#
#                              2              3            4    \
# mpg                         18.0           16.0         17.0
# cylinders                      8              8            8
# displacement               318.0          304.0        302.0
# horsepower                 150.0          150.0        140.0
# weight                      3436           3433         3449
# ...
